# %% [markdown]
# <a href="https://colab.research.google.com/github/freddy-7/TI2001B-2023/blob/main/1_Extracci%C3%B3n_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#INSTALAR LIBRERIAS
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 23.3.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#GOOGLE COLAB
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %% [markdown]
# CARGA DE ARCHIVO .CSV

# %%
#Convertir en dataframe
df_csv= pd.read_csv("Datos de Facturacion.excel")
df_csv

# %% [markdown]
# CARGA DE ARCHIVO XLSX

# %%
#Carga desde un archivo .xlsx sin indice
df= pd.read_excel('Datos de Facturación.xlsx')
df
# Out:
#       CVE_DOC    CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414        2465      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415        3926      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416        3926      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417        3926      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418        6813      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...         ...    ...       ...                     ...        ...
# 10890  F40306        8842      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307        6218    NaN       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892     NaN        5926      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309         361      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310        3011      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10895 entries, 0 to 10894
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CVE_DOC        10890 non-null  object
#  1   CVE_CLPV       10830 non-null  float64
#  2   STATUS         10886 non-null  object
#  3   CVE_VEND       10847 non-null  float64
#  4   FECHAELAB      10893 non-null  datetime64[ns]
#  5   FECHA_DOC      10894 non-null  datetime64[ns]
#  6   FECHA_ENT      10893 non-null  object
#  7   FECHA_VEN      10895 non-null  datetime64[ns]
#  8   FECHA_CANCELA  358 non-null    datetime64[ns]
#  9   CAN_TOT        10889 non-null  float64
#  10  DES_TOT        10894 non-null  float64
#  11  DES_FIN        10892 non-null  float64
# dtypes: datetime64[ns](4), float64(5), object(3)
# memory usage: 1021.5+ KB

# %%
#Imprimo los primeros 5 registro del dataframe
df.head()
# Out:
#   CVE_DOC  CVE_CLPV STATUS  CVE_VEND           FECHAELAB  FECHA_DOC  \
# 0  F29414    2465.0      C       1.0 2019-09-03 08:58:42 2019-09-03
# 1  F29415    3926.0      C       1.0 2019-09-03 09:55:14 2019-09-03
# 2  F29416    3926.0      C       1.0 2019-09-03 13:25:33 2019-09-03
# 3  F29417    3926.0      C       1.0 2019-09-03 13:33:23 2019-09-03
# 4  F29418    6813.0      C       2.0 2019-09-03 14:23:45 2019-09-03
#
#    FECHA_ENT  FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  DES_FIN
# 0 2019-09-03 2019-09-18    2019-09-04  3980.00      0.0      0.0
# 1 2019-09-03 2019-10-03    2019-09-03  1550.00      0.0      0.0
# 2 2019-09-03 2019-10-03    2019-09-03  1550.00      0.0      0.0
# 3 2019-09-03 2019-10-03    2019-09-17  1550.00      0.0      0.0
# 4 2019-09-03 2019-09-03    2019-09-10  2435.44      0.0      0.0

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUALITATIVAS**

# %%
#Filtro por objeto
filtro1=df[df["NOMBRE"] == "INDUSTRIAS LANCERMEX"]
filtro1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Cervantes\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NOMBRE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 2
#       1 #Filtro por objeto
# ...

# %%
#Filtro por filas
filtro2= df.iloc[7001:7100,: ]           #Filas consecutivas
#filtro2=df.iloc[ [8, 24, 100] , : ]  #Filas no consecutivas
filtro2
# Out:
#      CVE_DOC  CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 7001  F36417    5271.0      E       3.0 2021-10-15 08:40:29.183 2021-10-15
# 7002  F36418    5746.0      E       2.0 2021-10-15 08:51:03.463 2021-10-15
# 7003  F36419    2163.0      E       3.0 2021-10-15 08:56:23.280 2021-10-15
# 7004  F36420    1429.0      E       1.0 2021-10-15 09:01:08.393 2021-10-15
# 7005  F36421    5039.0      E       1.0 2021-10-15 09:07:07.103 2021-10-15
# ...      ...       ...    ...       ...                     ...        ...
# 7095  F36511    4480.0      E       2.0 2021-10-27 13:07:43.223 2021-10-27
# 7096  F36512    8186.0      E       2.0 2021-10-27 13:22:23.980 2021-10-27
# 7097  F36513    4403.0      E       2.0 2021-10-27 13:35:40.677 2021-10-27
# 7098  F36514    5589.0      E       2.0 2021-10-27 14:02:54.630 2021-10-27
# 7099  F36515    5589.0      E       2.0 2021-10-27 14:04:26.797 2021-10-27
#
#       FECHA_ENT  FECHA_VEN FECHA_CANCELA   CAN_TOT  DES_TOT  DES_FIN
# ...

# %%
#Filtro por columnas
#filtro3=df.iloc[ : , 0:3]       #Columnas consecutivas
filtro3=df.iloc[ : , [0,6,7,9]]  #Columnas no consecutivas
filtro3
# Out:
#       CVE_DOC  FECHA_ENT  FECHA_VEN  CAN_TOT
# 0      F29414 2019-09-03 2019-09-18  3980.00
# 1      F29415 2019-09-03 2019-10-03  1550.00
# 2      F29416 2019-09-03 2019-10-03  1550.00
# 3      F29417 2019-09-03 2019-10-03  1550.00
# 4      F29418 2019-09-03 2019-09-03  2435.44
# ...       ...        ...        ...      ...
# 10890  F40306 2023-03-01 2023-03-06  3272.00
# 10891  F40307 2023-03-06 2023-03-06   504.15
# 10892     NaN 2023-03-06 2023-03-06   275.68
# 10893  F40309 2023-03-07 2023-03-07   129.30
# 10894  F40310 2023-03-01 2023-03-07   517.20
#
# [10895 rows x 4 columns]

# %%
#GOOGLE COLAB
#Filtro de filas vs columnas
#Paso 1: Leemos el contenido del archivo
from google.colab import files
uploaded=files.upload()

# %%
df1= pd.read_excel('Datos de Facturación.xlsx', index_col=1)
df1
# Out:
#          CVE_DOC STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# CVE_CLPV
# 2465      F29414      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 3926      F29415      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 3926      F29416      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3926      F29417      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 6813      F29418      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...          ...    ...       ...                     ...        ...
# 8842      F40306      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 6218      F40307    NaN       2.0 2023-03-06 16:38:42.933 2023-03-06
# 5926         NaN      E       2.0 2023-03-06 17:02:33.390 2023-03-06
#  361      F40309      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 3011      F40310      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
#                     FECHA_ENT  FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  \
# CVE_CLPV
# ...

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas
filtro4=df1.loc[["HELVEX","DONGA HWASUNG MEXICO"], ["MONTO ADEUDADO"]]
filtro4

# %%
#Filtro por cabecera
filtro5=df.head(10)
filtro5

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUANTITATIVAS**

# %%
#Filtro por comparacion
df['FECHA_ENT'] = pd.to_datetime(df['FECHA_ENT'], errors='coerce')
#filtro6=df[df["FECHA_ENT"] == '28/02/2022 00:00']
filtro6 = df[df['FECHA_ENT'].dt.date == pd.to_datetime('28/02/2022').date()]
filtro6
# Out:
# C:\Users\Cervantes\AppData\Local\Temp\ipykernel_10860\4219448860.py:4: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   filtro6 = df[df['FECHA_ENT'].dt.date == pd.to_datetime('28/02/2022').date()]
#      CVE_DOC  CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 8077  F37493    4598.0      E       1.0 2022-02-28 10:56:02.460 2022-02-28
# 8078  F37494    1943.0      C       2.0 2022-02-28 11:34:00.367 2022-02-28
# 8081  F37497    1943.0      C       2.0 2022-02-28 12:05:42.377 2022-02-28
# 8083  F37499    8573.0      E       2.0 2022-02-28 12:25:29.833 2022-02-28
# 8084  F37500    8249.0      E       2.0 2022-02-28 12:32:46.687 2022-02-28
# 8090  F37506    1757.0      E       2.0 2022-02-28 13:23:45.440 2022-02-28
# 8091  F37507    3108.0      E       2.0 2022-02-28 13:52:43.383 2022-02-28
# ...

# %% [markdown]
# **FILTROS BASICOS CON CONETORES LOGICOS**

# %%
#Filtro Y
#df['CVE_CLPV'] = pd.to_numeric(df['CVE_CLPV'], errors='coerce')
#filtro7 = df[(df['CVE_VEND'] != 5) & (df['CVE_VEND'] != 4)] #utilizando el operador ! diferente de
#filtro7
# Paso 1: Filtra el DataFrame para las filas con CVE_VEND 1 o 2
df_filtrado = df[df['CVE_VEND'].isin([1, 2])]
filtro7 = df_filtrado.set_index('CVE_VEND')

filtro7
# Out:
#          CVE_DOC  CVE_CLPV STATUS               FECHAELAB  FECHA_DOC  \
# CVE_VEND
# 1.0       F29414    2465.0      C 2019-09-03 08:58:42.000 2019-09-03
# 1.0       F29415    3926.0      C 2019-09-03 09:55:14.000 2019-09-03
# 1.0       F29416    3926.0      C 2019-09-03 13:25:33.000 2019-09-03
# 1.0       F29417    3926.0      C 2019-09-03 13:33:23.000 2019-09-03
# 2.0       F29418    6813.0      C 2019-09-03 14:23:45.000 2019-09-03
# ...          ...       ...    ...                     ...        ...
# 2.0       F40306    8842.0      E 2023-03-06 16:09:39.013 2023-03-06
# 2.0       F40307    6218.0    NaN 2023-03-06 16:38:42.933 2023-03-06
# 2.0          NaN    5926.0      E 2023-03-06 17:02:33.390 2023-03-06
# 2.0       F40309     361.0      E 2023-03-07 12:43:49.567 2023-03-07
# 2.0       F40310    3011.0      E 2023-03-07 12:45:58.407 2023-03-07
#
#           FECHA_ENT  FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  DES_FIN
# CVE_VEND
# ...

# %%
#Filtro o
filtro8=df[(df["CAN_TOT"] < 5951.7) | (df["STATUS"] == "E")]
filtro8
# Out:
#       CVE_DOC  CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414    2465.0      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415    3926.0      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416    3926.0      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417    3926.0      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418    6813.0      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...       ...    ...       ...                     ...        ...
# 10890  F40306    8842.0      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307    6218.0    NaN       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892     NaN    5926.0      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309     361.0      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310    3011.0      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %%
#Filtro not
filtro9=df[~(df["MONTO ADEUDADO"] >= 6000)]
filtro9

# %%
#Convertir archivo filtrado a CSV
filtro7.to_csv("7-Index= CVE_VEND.csv")

# %%
#GOOGLE COLAB
#descardar archivo filtrado en csv
from google.colab import files


files.download("Entregable1.csv")
